# %%
# Install the required libraries
from IPython.display import clear_output
try:
  # !pip install pystan
  # !pip install fbprophet
  # !pip install hvplot
  # !pip install holoviews
except:
  print("Error installing libraries")
finally:
  clear_output()
  print('Libraries successfully installed')
# Out:
# Libraries successfully installed

# %%
# Import the required libraries and dependencies
import pandas as pd
import holoviews as hv
from fbprophet import Prophet
import hvplot.pandas
import datetime as dt
# %matplotlib inline
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Upload the "google_hourly_search_trends.csv" file into Colab, then store in a Pandas DataFrame
# Set the "Date" column as the Datetime Index.

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8d414ffa-b62a-468a-af80-2b2d4e363635" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d414ffa-b62a-468a-af80-2b2d4e363635">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving google_hourly_search_trends.csv to google_hourly_search_trends (1).csv

# %% [markdown]
# Step 1: Read the search data into a DataFrame, and then slice the data to just the month of May 2020. (During this month, MercadoLibre released its quarterly financial results.) Use hvPlot to visualize the results. Do any unusual patterns exist?

# %%
df_mercado_trends = pd.read_csv("google_hourly_search_trends.csv")

df_mercado_trends.head()
# Out:
#           Date  Search Trends
# 0  6/1/16 0:00             97
# 1  6/1/16 1:00             92
# 2  6/1/16 2:00             76
# 3  6/1/16 3:00             60
# 4  6/1/16 4:00             38

# %%
df_mercado_trends.set_index("Date", inplace=True)
df_mercado_trends.head()
# Out:
#              Search Trends
# Date
# 6/1/16 0:00             97
# 6/1/16 1:00             92
# 6/1/16 2:00             76
# 6/1/16 3:00             60
# 6/1/16 4:00             38

# %%
# Review the first and last five rows of the DataFrame
display(df_mercado_trends.shape)
display(df_mercado_trends.head())
display(df_mercado_trends.tail())
# Out:
# (37106, 1)
#              Search Trends
# Date
# 6/1/16 0:00             97
# 6/1/16 1:00             92
# 6/1/16 2:00             76
# 6/1/16 3:00             60
# 6/1/16 4:00             38
#               Search Trends
# Date
# 9/7/20 20:00             71
# 9/7/20 21:00             83
# 9/7/20 22:00             96
# 9/7/20 23:00             97
# 9/8/20 0:00              96

# %%
df_mercado_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37106 entries, 6/1/16 0:00 to 9/8/20 0:00
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Search Trends  37106 non-null  int64
# dtypes: int64(1)
# memory usage: 579.8+ KB

# %%
df_mercado_trends.index = pd.to_datetime(df_mercado_trends.index)
display(df_mercado_trends.shape)
display(df_mercado_trends.head())
display(df_mercado_trends.tail())
# Out:
# (37106, 1)
#                      Search Trends
# Date
# 2016-06-01 00:00:00             97
# 2016-06-01 01:00:00             92
# 2016-06-01 02:00:00             76
# 2016-06-01 03:00:00             60
# 2016-06-01 04:00:00             38
#                      Search Trends
# Date
# 2020-09-07 20:00:00             71
# 2020-09-07 21:00:00             83
# 2020-09-07 22:00:00             96
# 2020-09-07 23:00:00             97
# 2020-09-08 00:00:00             96

# %%
# Holoviews extension to render hvPlots in Colab
hv.extension('bokeh')

# Slice the DataFrame to just the month of May 2020
df_mercado_trends[df_mercado_trends.index.month == "May"]

# Use hvPlot to visualize the data for May 2020
df_mercado_trends["Search Trends"].hvplot()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Step 2: Calculate the total search traffic for the month, and then compare the value to the monthly median across all months. Did the Google search traffic increase during the month that MercadoLibre released its financial results?

# %%
# Calculate the sum of the total search traffic for May 2020
df_mercado_trends[df_mercado_trends.index.month == "May"]
df_mercado_trends = df_mercado_trends["Search Trends"].sum()
# View the traffic_may_2020 value
df_mercado_trends
# Out:
# 1785865

# %%
# Calculate the monhtly median search traffic across all months 
df_mercado_trends = df_mercado_trends["Search Trends"].median()
df_mercado_trends
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-19272f3691c7> in <module>()
#       1 # Calculate the monhtly median search traffic across all months
# ----> 2 df_mercado_trends = df_mercado_trends["Search Trends"].median()
#       3 df_mercado_trends
#
# IndexError: invalid index to scalar variable.

# %%
# Group the DataFrame by index year and then index month, chain the sum and then the median functions
median_monthly_traffic =

# View the median_monthly_traffic value

# %%
# Compare the seach traffic for the month of May 2020 to the overall monthly median value
